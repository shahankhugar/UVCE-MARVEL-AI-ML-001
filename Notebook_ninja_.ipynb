# %% [markdown]
# # 🧠 Notebook Ninja — Task 20
# ## UVCE MARVEL | AI-ML-001 | Shashank Hugar
#
# ---
#
# ## About Me
# I'm **Shashank Hugar**, a Mechanical Engineering student at **UVCE Bangalore**, exploring AI and ML through the MARVEL program.
#
# ## 3 Things I Want to Learn
# - How to build and train machine learning models
# - How to analyze real-world datasets
# - How to visualize data using Python
#
# ---

# %%
# Declaring variables and doing a calculation
name = "Shashank"
age = 20
gpa = 8.5

result = age * gpa

print(f"Name: {name}")
print(f"Age: {age}")
print(f"GPA: {gpa}")
print(f"Age x GPA = {result}")
# Out:
# Name: Shashank
# Age: 20
# GPA: 8.5
# Age x GPA = 170.0

# %% [markdown]
# ## 📸 Embedding an Image
#
# ![AI](https://upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Artificial_Intelligence_%26_AI_%26_Machine_Learning_-_30212411048.jpg/320px-Artificial_Intelligence_%26_AI_%26_Machine_Learning_-_30212411048.jpg)
#
# ---
#
# ## 💻 Code Snippet Example
# ```python
#     # This is how we declare variables in Python
#     x = 10
#     y = 20
#     print(x + y)  # Output: 30
# ```

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
scores = [55, 62, 70, 75, 85, 92]

plt.figure(figsize=(8, 4))
plt.plot(months, scores, marker="o", color="purple", linewidth=2)
plt.title("My Learning Progress Over 6 Months")
plt.xlabel("Month")
plt.ylabel("Score")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📝 Summary
#
# In this notebook I learned:
#
# - How to use **Markdown** to structure and format a notebook
# - How to **declare variables** and perform calculations in Python
# - How to create a **line plot** using Matplotlib
# - How to combine code, output and documentation in one place
#
# Jupyter Notebook is a powerful tool for data science and ML work!
#
# ---
# *UVCE MARVEL - AI-ML-001 | Level 1 | Task 20*
